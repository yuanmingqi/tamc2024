# %%
import pandas as pd

# %%
data = pd.read_excel('./TAMC2024_accepted_papers.xlsx')
data
# Out:
#     ID                                            Authors  \
# 0    4                 Nikolay Bazhenov and Manat Mustafa
# 1    5                                  Tomoyuki Yamakami
# 2    6                                   Shin-Ichi Nakano
# 3    7  Jiazhu Fang, Qizhi Fang, Wenjing Liu and Qingq...
# 4    9                      Jingyang Zhao and Mingyu Xiao
# 5   14                                         Xuehou Tan
# 6   15                               Zeyu Ren and Yan Liu
# 7   19                           Yuxi Liu and Mingyu Xiao
# 8   20                     Sunny Atalig and Marek Chrobak
# 9   23                                      Mike Cruchten
# 10  27                    Ivan Bliznets and Markus Hecher
# 11  28        Pierre Fraigniaud and Hovhannes Harutyunyan
# 12  32             Debajyoti Mondal and Md. Saidur Rahman
# 13  33                          Wenxuan Tao and Gang Chen
# 14  34                         Gaojie Chi and Longkun Guo
# ...

# %%
data['items'] = '- **' + data['Title'] + '**' + '\n\n' + '\t *' + data['Authors'] + '* \n'
data['items'].to_csv('accepted_papers.md', index=False, header=False, sep='\n')
